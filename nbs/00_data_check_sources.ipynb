# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import os
import json
import numpy as np
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="white", rc={"axes.facecolor": (0, 0, 0, 0)})
# %matplotlib inline

# %%
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# %%
BASE_PATH = '../../covid19-opendata-vaccini/dati'

START_DATE = '2021-01-01'
END_DATE = datetime.today().strftime('%Y-%m-%d')

# %%
for fn in os.listdir(BASE_PATH):
    if fn.endswith(".csv"):
        print('*'*80)
        print(fn)
        print(pd.read_csv(os.path.join(BASE_PATH, fn)).shape)
        display(pd.read_csv(os.path.join(BASE_PATH, fn)).head(1))
# Out:
# ********************************************************************************
# anagrafica-vaccini-summary-latest.csv
# (9, 8)
#   fascia_anagrafica   totale  sesso_maschile  sesso_femminile  prima_dose  \
# 0             12-19  1354766          667102           687664     1117043
#
#    seconda_dose  pregressa_infezione ultimo_aggiornamento
# 0        220361                17362           2021-07-11
# ********************************************************************************
# somministrazioni-vaccini-latest.csv
# (85570, 13)
#   data_somministrazione        fornitore area fascia_anagrafica  \
# 0            2020-12-27  Pfizer/BioNTech  ABR             20-29
#
#    sesso_maschile  sesso_femminile  prima_dose  seconda_dose  \
# 0               1                0           1             0
#
#    pregressa_infezione codice_NUTS1 codice_NUTS2  codice_regione_ISTAT  \
# 0                    0          ITF         ITF1                    13
#
#   nome_area
# 0   Abruzzo
# ...

# %%
vacc_df = pd.read_csv(os.path.join(BASE_PATH, 'somministrazioni-vaccini-latest.csv'))
print(vacc_df.shape)
vacc_df.head()
# Out:
# (85570, 13)
#   data_somministrazione        fornitore area fascia_anagrafica  \
# 0            2020-12-27  Pfizer/BioNTech  ABR             20-29
# 1            2020-12-27  Pfizer/BioNTech  ABR             30-39
# 2            2020-12-27  Pfizer/BioNTech  ABR             40-49
# 3            2020-12-27  Pfizer/BioNTech  ABR             50-59
# 4            2020-12-27  Pfizer/BioNTech  ABR             60-69
#
#    sesso_maschile  sesso_femminile  prima_dose  seconda_dose  \
# 0               1                0           1             0
# 1               1                3           4             0
# 2               1                6           7             0
# 3               4                5           9             0
# 4              10                4          14             0
#
#    pregressa_infezione codice_NUTS1 codice_NUTS2  codice_regione_ISTAT  \
# 0                    0          ITF         ITF1                    13
# ...
